# %% [markdown]
# <a href="https://colab.research.google.com/github/linashmyak/MLL/blob/main/ML1_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x = pd.read_csv("https://github.com/koroteevmv/ML_course/raw/main/ML1.2%20multivariate/data/0_x.csv")

# %%
x.head()
# Out:
#    0.07184119218267622  0.8553524138064769  -0.3055966142959303  \
# 0             0.139521           -0.423507             0.461059
# 1             1.626311           -0.257622            -0.697520
# 2            -1.183233           -0.826343             0.073047
# 3            -0.783365           -0.861232             0.951448
# 4             3.077357            0.948615            -0.295527
#
#    0.028252569993086545  1.8268953710701943
# 0             -0.447400           -0.034988
# 1              1.413219            1.086292
# 2             -0.639690           -0.503273
# 3             -0.117306            0.680597
# 4              1.390358           -0.116174

# %%
x = pd.read_csv("https://github.com/koroteevmv/ML_course/raw/main/ML1.2%20multivariate/data/0_x.csv",
                header=None)
y = pd.read_csv("https://github.com/koroteevmv/ML_course/raw/main/ML1.2%20multivariate/data/0_y.csv",
                header=None)

# %%
>>> x.shape, y.shape
((387, 5), (387, 1))

# %%
from sklearn.linear_model import LinearRegression

# %%
binary = LinearRegression()

# %%
binary.fit(x[[1]], y)
# Out:
# LinearRegression()

# %%
binary.coef_
# Out:
# array([[95.52010745]])

# %%
binary.predict(x[[1]])
# Out:
# array([[  81.7066754 ],
#        [ -40.45008468],
#        [ -24.60472955],
#        [ -78.92903986],
#        [ -82.26167214],
#        [  90.61516808],
#        [   3.20559483],
#        [ -27.39642608],
#        [  77.03125467],
#        [ -81.79074091],
#        [ -57.11517633],
#        [  71.55969853],
#        [ -51.83704209],
#        [  13.20326205],
#        [ -20.052765  ],
#        [ 125.1294343 ],
#        [ -85.37964253],
#        [ -67.97795874],
#        [  62.50833807],
#        [  67.06343892],
#        [ -62.27425459],
#        [ -80.86610767],
#        [ -27.05138056],
#        [ -52.78366471],
#        [  35.41921651],
#        [ -79.36741675],
#        [  56.64287014],
#        [  79.27353864],
#        [ -35.49555901],
#        [-221.02386024],
#        [ -80.76607115],
#        [ 165.15522994],
#        [  32.58309404],
#        [ -35.52849481],
#        [ -96.01738449],
#        [ -42.18812152],
#        [ -48.92932082],
#        [ -75.29745421],
#        [  14.5207672 ],
#        [  38.22303712],
#        [  -5.81538928],
#        [ -10.78305653],
#        [-160.67473236],
#        [ -24.04154649],
#        [ -11.539913  ],
#        [-153.21372804],
#        [  42.71613768],
#        [ -24.64631168],
#        [ -26.34379485],
#        [ -44.84902895],
#        [  40.59122298],
#        [  67.87447367],
#        [ 149.49931095],
#        [  -9.94584466],
#        [  72.09386938],
#        [  42.61221784],
#        [ -90.05010293],
#        [-195.17725103],
#        [  31.10609487],
#        [-179.11440495],
#        [ -68.01785401],
#        [  66.14535672],
#        [  46.04652432],
#        [-115.88877487],
#        [ -51.23726237],
#        [ -23.25825104],
#        [ 183.28767615],
#        [  42.06612485],
#        [ -61.68157548],
#        [  18.85284738],
#        [   8.29279789],
#        [  24.15702881],
#        [-132.25876571],
#        [-221.602558  ],
#        [  63.95970687],
#        [  70.05523606],
#        [ 101.35968876],
#        [  42.00528659],
#        [ -26.1669863 ],
#        [-142.57321028],
#        [  26.4302692 ],
#        [ -68.27127373],
#        [  77.68098549],
#        [   4.65591819],
#        [-275.75541696],
#        [ -18.03885794],
#        [ -65.15813567],
#        [  19.70062088],
#        [   2.30319232],
#        [-128.62567157],
#        [ -21.38042389],
#        [ 265.49792197],
#        [-232.79954877],
#        [  49.37518101],
#        [  46.59420205],
#        [ -66.70043384],
#        [ 135.3863095 ],
#        [ -20.73454969],
#        [ 153.12546539],
#        [  12.18146666],
#        [ -28.6152795 ],
#        [ 220.9291044 ],
#        [ -67.38550484],
#        [  54.67498213],
#        [ 146.49036594],
#        [-178.02357604],
#        [ 122.1816615 ],
#        [ -61.14413136],
#        [ -27.09696207],
#        [-162.71427576],
#        [ 250.11274891],
#        [-107.95714296],
#        [ -31.99055553],
#        [-125.12658808],
#        [ -43.28882518],
#        [ -48.08193349],
#        [ -14.84293043],
#        [ -49.99447436],
#        [  85.64858815],
#        [  48.0955124 ],
#        [ -12.70621587],
#        [ 106.29897038],
#        [ -18.39771021],
#        [ 131.8451858 ],
#        [ -49.15634037],
#        [   1.68833334],
#        [ 118.20821483],
#        [  93.32592767],
#        [  97.43196106],
#        [  41.90411351],
#        [-280.60718038],
#        [-197.29803704],
#        [ -81.67903369],
#        [ -31.55191845],
#        [  -8.98441752],
#        [  17.69645515],
#        [ -93.38459812],
#        [  39.46140888],
#        [ -10.04059876],
#        [ -45.14876349],
#        [ -75.91237642],
#        [-112.22661212],
#        [ 170.79517534],
#        [ 115.74079081],
#        [-162.39097497],
#        [ 105.17957504],
#        [ 154.74063944],
#        [  92.53223282],
#        [   6.9455845 ],
#        [-225.11827841],
#        [  63.11488128],
#        [  25.88212457],
#        [  39.19303711],
#        [ 141.26212896],
#        [ 122.432238  ],
#        [-263.473649  ],
#        [  -3.03374485],
#        [  97.40443477],
#        [  27.13542993],
#        [   5.3268769 ],
#        [ 109.40126709],
#        [ 187.77919778],
#        [  58.54396916],
#        [ 173.08930384],
#        [  -7.38389923],
#        [  -0.61716853],
#        [  15.9525564 ],
#        [ -56.74240282],
#        [  -9.43822359],
#        [ -12.58372954],
#        [  42.85873442],
#        [ -68.6263664 ],
#        [ -26.44110218],
#        [ -10.14910195],
#        [ -65.0326574 ],
#        [ 118.01212374],
#        [ 185.63095006],
#        [  80.68142722],
#        [ -22.36445142],
#        [  24.20376479],
#        [  91.92751024],
#        [ 123.84015615],
#        [  10.63661408],
#        [  38.14606475],
#        [  91.04662802],
#        [  -0.36732981],
#        [ 172.93200509],
#        [  15.84684686],
#        [  49.28739805],
#        [ -33.79697395],
#        [  54.96341913],
#        [ -10.50881915],
#        [-192.69059444],
#        [ -76.97685798],
#        [ 134.327864  ],
#        [ 111.50420719],
#        [ 126.56309706],
#        [-134.69906739],
#        [  75.62820656],
#        [  -1.70241194],
#        [  77.7070228 ],
#        [ -17.20936769],
#        [ 219.16998941],
#        [-136.13812314],
#        [ -66.21493546],
#        [ -55.27141374],
#        [ -70.4956149 ],
#        [ -43.24693497],
#        [  -7.07072434],
#        [ -20.91968838],
#        [ -40.80563876],
#        [ 141.13861597],
#        [  43.73042813],
#        [-195.48276684],
#        [   9.16176867],
#        [-105.62627143],
#        [ -10.67867476],
#        [   2.38472055],
#        [ 193.68921008],
#        [-115.63833686],
#        [  43.03267889],
#        [-147.37305219],
#        [  86.11484884],
#        [ -83.55847418],
#        [  30.71755434],
#        [  10.27639553],
#        [ -41.32557351],
#        [-140.26912202],
#        [ 128.01969105],
#        [ 183.95884118],
#        [   6.86531718],
#        [ -62.61269229],
#        [  66.06452798],
#        [ -47.63542055],
#        [ -85.17778107],
#        [ -15.72430026],
#        [  40.54649993],
#        [ -33.61879412],
#        [  31.76513237],
#        [-169.66712596],
#        [-110.88659879],
#        [ -77.04563955],
#        [  70.71761787],
#        [ -85.21453659],
#        [  41.92732181],
#        [ -13.68225282],
#        [ -67.49116957],
#        [  11.93379948],
#        [  50.18679576],
#        [ -21.66912636],
#        [  32.60453994],
#        [  14.09090855],
#        [ -27.33493738],
#        [-136.21711333],
#        [ -15.0605813 ],
#        [  49.78409122],
#        [-146.33455004],
#        [  71.63976509],
#        [  34.84132967],
#        [  12.30331257],
#        [  25.11261985],
#        [ -82.94602459],
#        [  83.54118867],
#        [ -57.88777693],
#        [  33.51754325],
#        [ -13.26429964],
#        [  65.85659717],
#        [  15.31444989],
#        [  67.81035688],
#        [  37.90075022],
#        [-167.10852275],
#        [ -57.99444761],
#        [ -36.00913797],
#        [  19.70290791],
#        [  33.45100315],
#        [-193.37192207],
#        [-121.15413667],
#        [  44.49224941],
#        [ -56.1373161 ],
#        [-153.69832577],
#        [ -80.50677918],
#        [-139.94014044],
#        [-192.67844919],
#        [ -54.64561087],
#        [  25.28740192],
#        [  25.07178482],
#        [   6.18083304],
#        [ 119.12500939],
#        [  46.71009304],
#        [  59.95782773],
#        [  83.74304754],
#        [ -99.02017347],
#        [ -87.68936548],
#        [  35.26396331],
#        [ 113.46685456],
#        [  42.5318588 ],
#        [  76.49714278],
#        [  99.83898538],
#        [ 112.30715761],
#        [ -12.15256336],
#        [ -29.02289519],
#        [  -6.97000698],
#        [ -37.7981597 ],
#        [ -52.4957794 ],
#        [ -98.02566506],
#        [ -18.49808937],
#        [ 134.54606734],
#        [ -21.78679736],
#        [  54.63789894],
#        [  59.63899484],
#        [ 157.32491005],
#        [  24.15363445],
#        [-121.14867961],
#        [ -32.74519018],
#        [-131.35579455],
#        [-100.53610905],
#        [  33.51745925],
#        [-221.78986989],
#        [  54.30924205],
#        [ -49.99624045],
#        [ -19.03749344],
#        [  -3.89300243],
#        [  -2.00342034],
#        [  69.27371782],
#        [ 234.02597915],
#        [  17.39055722],
#        [  14.93614571],
#        [ 148.66540159],
#        [  32.60167026],
#        [ 123.16186748],
#        [  61.24969494],
#        [  19.53920496],
#        [  25.02661721],
#        [ -75.38829513],
#        [ 166.41096829],
#        [ -47.99621481],
#        [ -25.77216712],
#        [ -48.96112576],
#        [ 105.43118884],
#        [   0.52022763],
#        [-336.85664107],
#        [  55.4750755 ],
#        [  72.33167816],
#        [-125.0236379 ],
#        [  20.70080008],
#        [ -57.91225848],
#        [  15.14114254],
#        [ -73.0099126 ],
#        [ 104.69214051],
#        [  50.24679881],
#        [  88.86557698],
#        [  68.28375578],
#        [ 122.95171668],
#        [ -25.0625463 ],
#        [  14.95429697],
#        [ -25.53926062],
#        [ 119.59087486],
#        [ 118.23947123],
#        [  43.99690047],
#        [ -21.1075395 ],
#        [ -17.25817459],
#        [  -2.62354642],
#        [  26.91692081],
#        [  10.15184644],
#        [  -9.48628965],
#        [ -81.84415436],
#        [ -68.05161774],
#        [-197.88761328],
#        [ -22.00916557],
#        [ 109.53859278],
#        [ -53.08749143],
#        [-153.71615885],
#        [  44.87328563],
#        [-157.42934885],
#        [-127.98274416],
#        [-166.53394014],
#        [ -61.33081485],
#        [ -11.77940539],
#        [  15.34513479],
#        [   3.0680711 ],
#        [-176.57818911],
#        [  13.43212536],
#        [ 221.67948236],
#        [ 200.32727577],
#        [  89.86779245],
#        [-115.55742864],
#        [  68.35801214]])

# %%
plt.scatter(x[1], y)
xx = np.linspace(x[1].min(), x[1].max(), 100).reshape((-1, 1))
plt.plot(xx, binary.predict(xx), c='r')

# %%
reg = LinearRegression()

# %%
reg.score(X, Y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-d3aeb5b0ea1e> in <cell line: 0>()
# ----> 1 reg.score(X, Y)
#
# NameError: name 'X' is not defined

# %%
multiple = LinearRegression()
multiple.fit(x, y)
multiple.score(x, y)
# Out:
# 0.9922198026415868

# %%
yy = multiple.predict(x)
plt.scatter(yy, y)
plt.plot(yy, yy, c='r')
